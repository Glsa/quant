# %% [markdown]
# <a href="https://colab.research.google.com/github/Glsa/quant/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tushare==1.2.85
# !pip install akshare -U
# !pip install backtrader==1.9.76.123
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.7.0
#     Uninstalling websocket-client-1.7.0:
#       Successfully uninstalled websocket-client-1.7.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 46.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 44.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 11.7 MB/s eta 0:00:00
# ...

# %%
# !pip install quantstats
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 742.8 kB/s eta 0:00:00
# ...

# %%
import backtrader as bt
import tushare as ts
import pandas as pd
import akshare as ak
from backtrader.feeds import PandasData
from datetime import datetime as dt
import warnings
import quantstats as qs
warnings.filterwarnings("ignore")

# %%
 fund_exchange_rank_em_df =ak.fund_exchange_rank_em()
 fund_exchange_rank_em_df
# Out:
#       序号    基金代码                  基金简称        类型          日期    单位净值    累计净值  \
# 0      1  513300    华夏纳斯达克100ETF(QDII)  指数型-海外股票  2024-03-13  1.6313  1.6313
# 1      2  159632    华安纳斯达克100ETF(QDII)  指数型-海外股票  2024-03-13  1.4787  1.4787
# 2      3  513100          国泰纳斯达克100ETF  指数型-海外股票  2024-03-13  1.2940  6.4700
# 3      4  159941          广发纳斯达克100ETF  指数型-海外股票  2024-03-13  0.9745  3.8980
# 4      5  513110  华泰柏瑞纳斯达克100ETF(QDII)  指数型-海外股票  2024-03-13  1.4879  1.4879
# ..   ...     ...                   ...       ...         ...     ...     ...
# 887  888  159586          南方中证全指计算机ETF    指数型-股票  2024-03-14  1.0074  1.0074
# 888  889  159591            富国中证A50ETF    指数型-股票  2024-03-08  1.0000  1.0000
# 889  890  159595            大成中证A50ETF    指数型-股票  2024-03-08  0.9997  0.9997
# 890  891  159593            平安中证A50ETF    指数型-股票  2024-03-14  1.0083  1.0083
# 891  892  159596            华宝中证A50ETF    指数型-股票  2024-03-08  0.9992  0.9992
#
# ...

# %%
fund_pool = fund_exchange_rank_em_df[fund_exchange_rank_em_df['基金简称'].str.contains('沪深300')].sort_values('成立日期').set_index('基金代码')
fund_pool.head()
# Out:
#          序号            基金简称      类型          日期    单位净值    累计净值   近1周   近1月  \
# 基金代码
# 510300  299    华泰柏瑞沪深300ETF  指数型-股票  2024-03-14  3.5542  1.5666  0.91  5.78
# 159919  295      嘉实沪深300ETF  指数型-股票  2024-03-14  3.6964  1.6635  0.91  5.79
# 510330  293      华夏沪深300ETF  指数型-股票  2024-03-14  3.6372  1.7812  0.91  5.80
# 159925  284      南方沪深300ETF  指数型-股票  2024-03-14  3.5598  1.5716  0.91  5.81
# 510310  283  易方达沪深300发起式ETF  指数型-股票  2024-03-14  1.7369  1.7369  0.91  5.82
#
#          近3月   近6月   近1年    近2年    近3年   今年来    成立来        成立日期
# 基金代码
# 510300  6.18 -4.63 -8.86 -11.69 -27.27  3.66  57.95  2012-05-04
# 159919  6.19 -4.59 -8.79 -11.45 -26.95  3.67  64.33  2012-05-07
# 510330  6.21 -4.53 -8.73 -11.37 -27.03  3.69  80.98  2012-12-25
# 159925  6.24 -4.55 -8.45 -10.74 -25.64  3.71  79.25  2013-02-18
# 510310  6.28 -4.40 -8.41 -10.58 -25.75  3.75  73.69  2013-03-06

# %%
fund = fund_pool.index[0]
fund
# Out:
# '510300'

# %%
fund_etf_fund_info_em_df = ak.fund_etf_fund_info_em(fund=fund, start_date='20150101', end_date='20240315')

# %%
fund_etf_fund_info_em_df
# Out:
#             净值日期    单位净值    累计净值  日增长率  申购状态  赎回状态
# 0     2015-01-05  3.6782  1.3945  3.05  场内买入  场内卖出
# 1     2015-01-06  3.6757  1.3935 -0.07  场内买入  场内卖出
# 2     2015-01-07  3.6741  1.3930 -0.04  场内买入  场内卖出
# 3     2015-01-08  3.5884  1.3612 -2.33  场内买入  场内卖出
# 4     2015-01-09  3.5749  1.3562 -0.38  场内买入  场内卖出
# ...          ...     ...     ...   ...   ...   ...
# 2238  2024-03-08  3.5373  1.5603  0.43  场内买入  场内卖出
# 2239  2024-03-11  3.5813  1.5766  1.24  场内买入  场内卖出
# 2240  2024-03-12  3.5895  1.5797  0.23  场内买入  场内卖出
# 2241  2024-03-13  3.5644  1.5704 -0.70  场内买入  场内卖出
# 2242  2024-03-14  3.5542  1.5666 -0.29  场内买入  场内卖出
#
# [2243 rows x 6 columns]

# %%
fund_etf_fund_info_em_df.rename(columns={'净值日期':'date','累计净值': 'close'}, inplace=True)
fund_etf_fund_info_em_df = fund_etf_fund_info_em_df[['date', 'close']]
fund_etf_fund_info_em_df
# Out:
#             date   close
# 0     2015-01-05  1.3945
# 1     2015-01-06  1.3935
# 2     2015-01-07  1.3930
# 3     2015-01-08  1.3612
# 4     2015-01-09  1.3562
# ...          ...     ...
# 2238  2024-03-08  1.5603
# 2239  2024-03-11  1.5766
# 2240  2024-03-12  1.5797
# 2241  2024-03-13  1.5704
# 2242  2024-03-14  1.5666
#
# [2243 rows x 2 columns]

# %%
fund_etf_fund_info_em_df['open'] = fund_etf_fund_info_em_df['close']
fund_etf_fund_info_em_df['high'] = fund_etf_fund_info_em_df['close']
fund_etf_fund_info_em_df['low'] = fund_etf_fund_info_em_df['close']
fund_etf_fund_info_em_df['volume'] = 1000

fund_etf_fund_info_em_df = fund_etf_fund_info_em_df[['date','open','high','low','close','volume']]
fund_etf_fund_info_em_df
# Out:
#            date    open    high     low   close  volume
# 0    2015-01-05  1.3945  1.3945  1.3945  1.3945    1000
# 1    2015-01-06  1.3935  1.3935  1.3935  1.3935    1000
# 2    2015-01-07  1.3930  1.3930  1.3930  1.3930    1000
# 3    2015-01-08  1.3612  1.3612  1.3612  1.3612    1000
# 4    2015-01-09  1.3562  1.3562  1.3562  1.3562    1000
# ...         ...     ...     ...     ...     ...     ...
# 2238 2024-03-08  1.5603  1.5603  1.5603  1.5603    1000
# 2239 2024-03-11  1.5766  1.5766  1.5766  1.5766    1000
# 2240 2024-03-12  1.5797  1.5797  1.5797  1.5797    1000
# 2241 2024-03-13  1.5704  1.5704  1.5704  1.5704    1000
# 2242 2024-03-14  1.5666  1.5666  1.5666  1.5666    1000
#
# [2243 rows x 6 columns]

# %%
fund_etf_fund_info_em_df.date = pd.to_datetime(fund_etf_fund_info_em_df.date)

# %%
start_date = '20150101'
end_date = '20220101'

# %%
# 8 编写策略类

class SmaCross(bt.Strategy):
  params = dict(
      period_fast=5,
      period_slow=10
  )
  def _init_(self):
    self.move_average_fast = bt.ind.MovingAverageSimple(self.datas[0].close, period=self.params.period_fast)
    self.move_average_slow = bt.ind.MovingAverageSimple(self.datas[0].close, period=self.params.period_slow)

  def next(self):
    size = int(self.broker.getvalue()/self.data[0].close//100*100)
    if not self.position.size:
      if self.move_average_fast.sma[-1] < self.move_average_slow.sma[-1] and self.move_average_fast.sma[0] > self.move_average_slow.sma[0]:
        self.buy(size=size)
    elif self.move_average_fast.sma[-1] > self.move_average_slow.sma[-1] and self.move_average_fast.sma[0] < self.move_average_slow.sma[0]:
      self.close()

# %%
# 回测

cerebro = bt.Cerebro()
etf_data = PandasData(
    dataname = fund_etf_fund_info_em_df,
    datetime=0,
    open=1,
    high=2,
    low=3,
    close=4,
    volume=5,
    fromdate=dt.strptime(start_date, '%Y%m%d'),
    todate=dt.strptime(end_date, '%Y%m%d'),
)
cerebro.adddata(etf_data, name='etf')
start_cash=100000
cerebro.addstrategy(SmaCross)
cerebro.broker.setcash(start_cash)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='PyFolio')

print('最终市值： %.2f' % cerebro.broker.getvalue())
results = cerebro.run()
strat = results[0]

portfolio_stats = strat.analyzers.getbyname('PyFolio')
returns, _, _, _ = portfolio_stats.get_pf_items()
returns.index=returns.index.tz_convert(None)
qs.reports.full(returns)
# Out:
# 最终市值： 100000.00
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-4293ead5ada0> in <cell line: 22>()
#      20
#      21 print('最终市值： %.2f' % cerebro.broker.getvalue())
# ---> 22 results = cerebro.run()
#      23 strat = results[0]
#      24
#
# /usr/local/lib/python3.10/dist-packages/backtrader/cerebro.py in run(self, **kwargs)
#    1125             # let's skip process "spawning"
#    1126             for iterstrat in iterstrats:
# -> 1127                 runstrat = self.runstrategies(iterstrat)
#    1128                 self.runstrats.append(runstrat)
#    1129                 if self._dooptimize:
#
# /usr/local/lib/python3.10/dist-packages/backtrader/cerebro.py in runstrategies(self, iterstrat, predata)
#    1291                     self._runonce_old(runstrats)
#    1292                 else:
# -> 1293                     self._runonce(runstrats)
# ...
